# %% [markdown]
# # The supervised-learning contract
#
# **Lecture 9 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory will begin with the claim rather than the algorithm: observation unit, population, prediction time, target horizon, available features, loss, deployment path, and outcome feedback.

# %% [markdown]
# ## Development map
#
# The classroom-ready revision will build a battery-cell prediction contract, demonstrate group and time leakage, compare honest baselines, and move a baseline artifact through training, prediction, and delayed-outcome collection. This initial notebook fixes the executable entry point while the detailed laboratory is developed.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Part II laboratory environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Laboratory boundary
#
# A notebook can expose assumptions and run a bounded experiment. Reusable splitters, schemas, metrics, and artifact interfaces must graduate into `rice_dsm`, with tests and CI preserving their contracts.
