# %% [markdown]
# # Affine models and least squares
#
# **Lecture 10 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory connects the affine map to least-squares estimation, geometry, optimization, numerical conditioning, regularization, and regression diagnostics.

# %% [markdown]
# ## Development map
#
# The full notebook will derive the objective, compare closed-form and iterative solutions, test scaling and collinearity failures, and package a leakage-safe regression pipeline for the running battery case.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Regression laboratory environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Contract to preserve
#
# A fitted coefficient is not automatically stable, causal, or useful. The finished laboratory must report the population, units, split, transformation fit, residual behavior, and out-of-sample error.
