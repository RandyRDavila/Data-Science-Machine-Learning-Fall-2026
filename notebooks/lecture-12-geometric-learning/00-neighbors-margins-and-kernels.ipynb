# %% [markdown]
# # Neighbors, margins, and kernels
#
# **Lecture 12 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory asks when distance, similarity, or margin is a defensible basis for prediction.

# %% [markdown]
# ## Development map
#
# The detailed version will compare k-nearest neighbors with support-vector methods, expose the effect of scaling and irrelevant dimensions, and measure both validation quality and prediction latency.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Geometric-learning environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Contract to preserve
#
# Preprocessing defines the geometry. It must be fitted inside each training fold, serialized with the learner, and justified by the meaning and units of the features.
