# %% [markdown]
# # Recursive partitioning with decision trees
#
# **Lecture 13 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory treats a tree as a piecewise-constant function constructed by greedy recursive partitioning.

# %% [markdown]
# ## Development map
#
# The full notebook will compute split criteria, visualize partitions, study depth and pruning, perturb the sample to expose instability, and test prediction behavior at learned thresholds.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Decision-tree environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Contract to preserve
#
# A path through a fitted tree explains how that model produced one output. It does not by itself explain the physical cause of the outcome.
