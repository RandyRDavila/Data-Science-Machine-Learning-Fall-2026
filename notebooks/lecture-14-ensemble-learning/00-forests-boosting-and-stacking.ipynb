# %% [markdown]
# # Forests, boosting, and stacking
#
# **Lecture 14 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory compares ensemble mechanisms instead of treating every collection of models as the same idea.

# %% [markdown]
# ## Development map
#
# The completed sequence will cover bagging, random forests, extra trees, AdaBoost, gradient boosting, voting, and leakage-safe stacking with out-of-fold predictions.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Ensemble laboratory environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Contract to preserve
#
# A more accurate ensemble may cost more memory, latency, energy, calibration work, and explanation effort. Candidate comparison must include those constraints.
