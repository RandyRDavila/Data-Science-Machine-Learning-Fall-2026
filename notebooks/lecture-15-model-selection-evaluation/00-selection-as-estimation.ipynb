# %% [markdown]
# # Model selection as an estimation problem
#
# **Lecture 15 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory asks what a validation result estimates and how repeated choices can make that estimate optimistic.

# %% [markdown]
# ## Development map
#
# The full sequence will compare splitters, construct leakage-safe pipelines, perform bounded search and nested evaluation, quantify uncertainty, and write an explicit promotion decision.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Model-selection environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Contract to preserve
#
# The test set is not a leaderboard queried until a pleasing result appears. Every adaptive choice spends information and must remain inside the selection boundary.
