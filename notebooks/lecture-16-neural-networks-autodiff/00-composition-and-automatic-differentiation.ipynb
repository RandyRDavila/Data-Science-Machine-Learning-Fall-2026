# %% [markdown]
# # Neural composition and automatic differentiation
#
# **Lecture 16 · Notebook 00 · CMOR 438 / INDE 577**
#
# This laboratory begins with the familiar affine map, adds nonlinear composition, and makes the computational graph behind gradient calculation explicit.

# %% [markdown]
# ## Development map
#
# One tiny network will receive a manual forward and backward pass plus a finite-difference gradient check. Routine training will then move to a modern automatic-differentiation framework.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Neural-network environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Contract to preserve
#
# Autodiff computes derivatives of the implemented graph. It does not choose the target, loss, split, architecture, optimization schedule, or scientific interpretation.
