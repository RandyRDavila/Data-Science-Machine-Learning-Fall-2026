# %% [markdown]
# # Training, prediction, and feedback paths
#
# **Lecture 17 · Notebook 00 · CMOR 438 / INDE 577**
#
# This capstone laboratory connects the three paths required by an operated supervised-learning system.

# %% [markdown]
# ## Development map
#
# The finished capstone will produce a manifest, versioned model artifact, batch or API prediction path, outcome join, monitoring specification, promotion gate, and tested rollback rehearsal.

# %%
import rice_dsm

assert rice_dsm.__version__
print(f"Supervised-system capstone environment ready: rice-dsm {rice_dsm.__version__}")

# %% [markdown]
# ## Claim boundary
#
# A locally executed vertical slice is evidence about the boundaries it actually exercises. It is not evidence that a hosted service is reliable, that future data are unchanged, or that the prediction should control a consequential action without governance.
